# %%
import pyspark

# %%
sc = pyspark.SparkContext()

# %%
import random

# %%
arr = [chr(random.randint(65, 91)) for i in range(10000)]

# %%
arr
# Out:
# ['N',
#  'H',
#  'Q',
#  'O',
#  'O',
#  'W',
#  'P',
#  'L',
#  'N',
#  'W',
#  'G',
#  'H',
#  'B',
#  'A',
#  'D',
#  'I',
#  'H',
#  'E',
#  'T',
#  'G',
#  'G',
#  'V',
#  'Y',
#  'X',
#  'E',
#  'V',
#  'T',
#  'A',
#  'W',
#  'M',
#  'O',
#  'Z',
#  'V',
#  'L',
#  'O',
#  '[',
#  'M',
#  'A',
#  'D',
#  'R',
#  'R',
#  'J',
#  'M',
#  'R',
#  'V',
#  'L',
#  'G',
#  'P',
#  'R',
#  'B',
#  'A',
#  'B',
#  'V',
#  'F',
#  'O',
#  'Z',
#  'D',
#  'U',
#  'H',
#  'W',
#  'R',
#  'O',
#  'A',
#  'O',
#  'D',
#  'A',
#  'A',
#  'V',
#  'A',
#  'T',
#  'S',
#  'B',
#  'T',
#  'Y',
#  'K',
#  'A',
#  'L',
#  'Z',
#  'P',
#  'T',
#  'W',
#  'V',
#  'M',
#  'J',
#  'F',
#  'Z',
#  'U',
#  'L',
#  'B',
#  'Z',
#  '[',
#  'R',
#  'E',
#  'Z',
#  'M',
#  'T',
#  'R',
#  'F',
#  'N',
#  '[',
#  'X',
#  'A',
#  'G',
#  'G',
#  '[',
#  'J',
#  'S',
#  'B',
#  'V',
#  'R',
#  'W',
#  'E',
#  'C',
#  'U',
#  'L',
#  'B',
#  'H',
#  'S',
#  'R',
#  'T',
#  'T',
#  'H',
#  'L',
#  'I',
#  'P',
# ...

# %%
rdd = sc.parallelize(arr)

# %%
rdd
# Out:
# ParallelCollectionRDD[0] at parallelize at PythonRDD.scala:195

# %%
rdd.count()
# Out:
# 10000
